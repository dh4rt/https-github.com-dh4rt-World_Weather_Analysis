# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
# YOUR CODE HERE
cities = []
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 813

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8e99e4875a6b849c43b245f3ff50fcaf

# %%
#url = "http://api.openweathermap.org/geo/1.0/reverse?lat=&lon=&limit=2000&appid=" + weather_api_key
#print(url)

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_crnt = city_weather["weather"][0]["description"]     
        city_cloud = city_weather["clouds"]["all"]
       
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_weather['sys']['country'],
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_crnt,
                          "Cloudiness": city_cloud
                          })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hilo
# Processing Record 2 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 1 | tasiilaq
# Processing Record 4 of Set 1 | tuatapere
# Processing Record 5 of Set 1 | jambi
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | bilma
# Processing Record 11 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 1 | padang
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | kapaa
# Processing Record 16 of Set 1 | longyearbyen
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | fukue
# Processing Record 19 of Set 1 | hithadhoo
# Processing Record 20 of Set 1 | hermanus
# Processing Record 21 of Set 1 | rawannawi
# City not found. Skipping...
# Processing Record 22 of Set 1 | atuona
# Processing Record 23 of Set 1 | faanui
# Processing Record 24 of Set 1 | honningsvag
# Processing Record 25 of Set 1 | barrow
# Processing Record 26 of Set 1 | aklavik
# Processing Record 27 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 28 of Set 1 | pasni
# Processing Record 29 of Set 1 | butaritari
# Processing Record 30 of Set 1 | constitucion
# Processing Record 31 of Set 1 | bethel
# Processing Record 32 of Set 1 | yunjinghong
# City not found. Skipping...
# Processing Record 33 of Set 1 | novovelichkovskaya
# Processing Record 34 of Set 1 | mount isa
# Processing Record 35 of Set 1 | upernavik
# Processing Record 36 of Set 1 | hanstholm
# Processing Record 37 of Set 1 | gra liyia
# Processing Record 38 of Set 1 | cabo san lucas
# Processing Record 39 of Set 1 | zapolyarnyy
# Processing Record 40 of Set 1 | kodiak
# Processing Record 41 of Set 1 | kirakira
# Processing Record 42 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 1 | nago
# Processing Record 44 of Set 1 | sibolga
# Processing Record 45 of Set 1 | lewiston
# Processing Record 46 of Set 1 | port alfred
# Processing Record 47 of Set 1 | port-cartier
# Processing Record 48 of Set 1 | kaili
# Processing Record 49 of Set 1 | busselton
# Processing Record 50 of Set 1 | narasannapeta
# Processing Record 1 of Set 2 | wanaka
# Processing Record 2 of Set 2 | bluff
# Processing Record 3 of Set 2 | jhinjhak
# Processing Record 4 of Set 2 | arraial do cabo
# Processing Record 5 of Set 2 | batagay
# Processing Record 6 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 2 | batagay-alyta
# Processing Record 8 of Set 2 | innisfail
# Processing Record 9 of Set 2 | baiyin
# Processing Record 10 of Set 2 | chalmette
# Processing Record 11 of Set 2 | mattru
# Processing Record 12 of Set 2 | cherskiy
# Processing Record 13 of Set 2 | thompson
# Processing Record 14 of Set 2 | ponta do sol
# Processing Record 15 of Set 2 | ayorou
# Processing Record 16 of Set 2 | kindu
# Processing Record 17 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 2 | shenkursk
# Processing Record 19 of Set 2 | avarua
# Processing Record 20 of Set 2 | buala
# Processing Record 21 of Set 2 | sao gabriel da cachoeira
# Processing Record 22 of Set 2 | lisakovsk
# Processing Record 23 of Set 2 | lebu
# Processing Record 24 of Set 2 | souillac
# Processing Record 25 of Set 2 | ballina
# Processing Record 26 of Set 2 | punta arenas
# Processing Record 27 of Set 2 | san patricio
# Processing Record 28 of Set 2 | tuktoyaktuk
# Processing Record 29 of Set 2 | kahului
# Processing Record 30 of Set 2 | hami
# Processing Record 31 of Set 2 | new norfolk
# Processing Record 32 of Set 2 | hobart
# Processing Record 33 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 35 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 2 | sao felix do xingu
# Processing Record 37 of Set 2 | pimenta bueno
# Processing Record 38 of Set 2 | castro
# Processing Record 39 of Set 2 | esperance
# Processing Record 40 of Set 2 | mapiri
# Processing Record 41 of Set 2 | little current
# Processing Record 42 of Set 2 | osoyoos
# Processing Record 43 of Set 2 | susuman
# Processing Record 44 of Set 2 | cape town
# Processing Record 45 of Set 2 | bambous virieux
# Processing Record 46 of Set 2 | biak
# Processing Record 47 of Set 2 | yanan
# City not found. Skipping...
# Processing Record 48 of Set 2 | provideniya
# Processing Record 49 of Set 2 | ostersund
# Processing Record 50 of Set 2 | tunduru
# City not found. Skipping...
# Processing Record 1 of Set 3 | ribeira grande
# Processing Record 2 of Set 3 | council bluffs
# Processing Record 3 of Set 3 | macaubas
# Processing Record 4 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 3 | slave lake
# Processing Record 6 of Set 3 | mareeba
# Processing Record 7 of Set 3 | tura
# Processing Record 8 of Set 3 | haines junction
# Processing Record 9 of Set 3 | saskylakh
# Processing Record 10 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 3 | manaure
# Processing Record 12 of Set 3 | puerto ayora
# Processing Record 13 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 3 | ormara
# Processing Record 15 of Set 3 | krasnoselkup
# Processing Record 16 of Set 3 | bodaybo
# Processing Record 17 of Set 3 | vardo
# Processing Record 18 of Set 3 | cidreira
# Processing Record 19 of Set 3 | camapua
# Processing Record 20 of Set 3 | severo-kurilsk
# Processing Record 21 of Set 3 | christchurch
# Processing Record 22 of Set 3 | ardalstangen
# Processing Record 23 of Set 3 | iqaluit
# Processing Record 24 of Set 3 | zhezkazgan
# Processing Record 25 of Set 3 | chokurdakh
# Processing Record 26 of Set 3 | port blair
# Processing Record 27 of Set 3 | bengkulu
# Processing Record 28 of Set 3 | bar harbor
# Processing Record 29 of Set 3 | tupik
# Processing Record 30 of Set 3 | chatra
# Processing Record 31 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 3 | hualmay
# Processing Record 33 of Set 3 | port elizabeth
# Processing Record 34 of Set 3 | san jose de guanipa
# Processing Record 35 of Set 3 | geraldton
# Processing Record 36 of Set 3 | san pedro
# Processing Record 37 of Set 3 | camana
# Processing Record 38 of Set 3 | yining
# Processing Record 39 of Set 3 | katsuura
# Processing Record 40 of Set 3 | mar del plata
# Processing Record 41 of Set 3 | nador
# Processing Record 42 of Set 3 | portland
# Processing Record 43 of Set 3 | tiksi
# Processing Record 44 of Set 3 | husavik
# Processing Record 45 of Set 3 | nikolskoye
# Processing Record 46 of Set 3 | san jose
# Processing Record 47 of Set 3 | grimshaw
# Processing Record 48 of Set 3 | ginda
# Processing Record 49 of Set 3 | grand gaube
# Processing Record 50 of Set 3 | lasa
# Processing Record 1 of Set 4 | jamestown
# Processing Record 2 of Set 4 | ogawara
# Processing Record 3 of Set 4 | wagga wagga
# Processing Record 4 of Set 4 | ponta delgada
# Processing Record 5 of Set 4 | ancud
# Processing Record 6 of Set 4 | sao filipe
# Processing Record 7 of Set 4 | pangnirtung
# Processing Record 8 of Set 4 | temir
# Processing Record 9 of Set 4 | eskasem
# City not found. Skipping...
# Processing Record 10 of Set 4 | vredendal
# Processing Record 11 of Set 4 | sterling
# Processing Record 12 of Set 4 | ustka
# Processing Record 13 of Set 4 | kokopo
# Processing Record 14 of Set 4 | pontianak
# Processing Record 15 of Set 4 | shingu
# Processing Record 16 of Set 4 | chapleau
# Processing Record 17 of Set 4 | salalah
# Processing Record 18 of Set 4 | okhotsk
# Processing Record 19 of Set 4 | quelimane
# Processing Record 20 of Set 4 | kumluca
# Processing Record 21 of Set 4 | klaksvik
# Processing Record 22 of Set 4 | sao joao da barra
# Processing Record 23 of Set 4 | kiunga
# Processing Record 24 of Set 4 | saint-joseph
# Processing Record 25 of Set 4 | yerbogachen
# Processing Record 26 of Set 4 | sept-iles
# Processing Record 27 of Set 4 | kavieng
# Processing Record 28 of Set 4 | verkhnyaya toyma
# Processing Record 29 of Set 4 | qui nhon
# Processing Record 30 of Set 4 | bardiyah
# Processing Record 31 of Set 4 | carnarvon
# Processing Record 32 of Set 4 | chuy
# Processing Record 33 of Set 4 | pak phanang
# Processing Record 34 of Set 4 | shimanovsk
# Processing Record 35 of Set 4 | serebryanyy bor
# Processing Record 36 of Set 4 | ajdabiya
# Processing Record 37 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 38 of Set 4 | wawa
# Processing Record 39 of Set 4 | njombe
# Processing Record 40 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 41 of Set 4 | cuambog
# Processing Record 42 of Set 4 | chibuto
# Processing Record 43 of Set 4 | pandan
# Processing Record 44 of Set 4 | vanavara
# Processing Record 45 of Set 4 | great falls
# Processing Record 46 of Set 4 | dvinskoy
# Processing Record 47 of Set 4 | khani
# Processing Record 48 of Set 4 | tarakan
# Processing Record 49 of Set 4 | luderitz
# Processing Record 50 of Set 4 | kavaratti
# Processing Record 1 of Set 5 | voh
# Processing Record 2 of Set 5 | lavrentiya
# Processing Record 3 of Set 5 | grindavik
# Processing Record 4 of Set 5 | san quintin
# Processing Record 5 of Set 5 | piacabucu
# Processing Record 6 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 7 of Set 5 | alamosa
# Processing Record 8 of Set 5 | port hedland
# Processing Record 9 of Set 5 | viedma
# Processing Record 10 of Set 5 | half moon bay
# Processing Record 11 of Set 5 | ekibastuz
# Processing Record 12 of Set 5 | vestnes
# Processing Record 13 of Set 5 | vila velha
# Processing Record 14 of Set 5 | umm lajj
# Processing Record 15 of Set 5 | sibu
# Processing Record 16 of Set 5 | victoria
# Processing Record 17 of Set 5 | catalina
# Processing Record 18 of Set 5 | fairbanks
# Processing Record 19 of Set 5 | khatanga
# Processing Record 20 of Set 5 | nahan
# Processing Record 21 of Set 5 | kulunda
# Processing Record 22 of Set 5 | port lincoln
# Processing Record 23 of Set 5 | livingstonia
# Processing Record 24 of Set 5 | vao
# Processing Record 25 of Set 5 | la ronge
# Processing Record 26 of Set 5 | constancia
# Processing Record 27 of Set 5 | channel-port aux basques
# Processing Record 28 of Set 5 | kisesa
# Processing Record 29 of Set 5 | assai
# Processing Record 30 of Set 5 | mercedes
# Processing Record 31 of Set 5 | sitka
# Processing Record 32 of Set 5 | nara
# Processing Record 33 of Set 5 | namibe
# Processing Record 34 of Set 5 | komsomolskiy
# Processing Record 35 of Set 5 | samarai
# Processing Record 36 of Set 5 | jiblah
# Processing Record 37 of Set 5 | alghero
# Processing Record 38 of Set 5 | wajima
# Processing Record 39 of Set 5 | dunedin
# Processing Record 40 of Set 5 | luoyang
# Processing Record 41 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 5 | talnakh
# Processing Record 43 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 44 of Set 5 | ust-kuyga
# Processing Record 45 of Set 5 | axim
# Processing Record 46 of Set 5 | san juan del sur
# Processing Record 47 of Set 5 | miandrivazo
# Processing Record 48 of Set 5 | ternate
# Processing Record 49 of Set 5 | beloha
# Processing Record 50 of Set 5 | caravelas
# Processing Record 1 of Set 6 | presidencia roque saenz pena
# Processing Record 2 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 3 of Set 6 | north bend
# Processing Record 4 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 5 of Set 6 | mopti
# Processing Record 6 of Set 6 | meadow lake
# Processing Record 7 of Set 6 | ostrovnoy
# Processing Record 8 of Set 6 | yenagoa
# Processing Record 9 of Set 6 | zharkent
# Processing Record 10 of Set 6 | bogotol
# Processing Record 11 of Set 6 | bredasdorp
# Processing Record 12 of Set 6 | mitsamiouli
# Processing Record 13 of Set 6 | okandja
# City not found. Skipping...
# Processing Record 14 of Set 6 | camabatela
# Processing Record 15 of Set 6 | hovd
# Processing Record 16 of Set 6 | kalmunai
# Processing Record 17 of Set 6 | bathsheba
# Processing Record 18 of Set 6 | carballo
# Processing Record 19 of Set 6 | mount gambier
# Processing Record 20 of Set 6 | taoudenni
# Processing Record 21 of Set 6 | aksu
# Processing Record 22 of Set 6 | saint anthony
# Processing Record 23 of Set 6 | naze
# Processing Record 24 of Set 6 | kidal
# Processing Record 25 of Set 6 | saint george
# Processing Record 26 of Set 6 | harper
# Processing Record 27 of Set 6 | zalantun
# Processing Record 28 of Set 6 | lagoa
# Processing Record 29 of Set 6 | maku
# Processing Record 30 of Set 6 | saint-philippe
# Processing Record 31 of Set 6 | berdigestyakh
# Processing Record 32 of Set 6 | dikson
# Processing Record 33 of Set 6 | dhidhdhoo
# Processing Record 34 of Set 6 | ati
# Processing Record 35 of Set 6 | lagos
# Processing Record 36 of Set 6 | sechura
# Processing Record 37 of Set 6 | coquimbo
# Processing Record 38 of Set 6 | mayya
# Processing Record 39 of Set 6 | shimoda
# Processing Record 40 of Set 6 | hecun
# Processing Record 41 of Set 6 | rangapara
# Processing Record 42 of Set 6 | touros
# Processing Record 43 of Set 6 | ocos
# Processing Record 44 of Set 6 | codrington
# Processing Record 45 of Set 6 | cockburn town
# Processing Record 46 of Set 6 | vicuna
# Processing Record 47 of Set 6 | segovia
# Processing Record 48 of Set 6 | wulanhaote
# City not found. Skipping...
# Processing Record 49 of Set 6 | vila
# Processing Record 50 of Set 6 | bilibino
# Processing Record 1 of Set 7 | kenai
# Processing Record 2 of Set 7 | mangai
# Processing Record 3 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 7 | berezivka
# Processing Record 5 of Set 7 | grand-lahou
# Processing Record 6 of Set 7 | kulhudhuffushi
# Processing Record 7 of Set 7 | eastbourne
# Processing Record 8 of Set 7 | vaitape
# Processing Record 9 of Set 7 | qidong
# Processing Record 10 of Set 7 | mahebourg
# Processing Record 11 of Set 7 | kruglolesskoye
# Processing Record 12 of Set 7 | east london
# Processing Record 13 of Set 7 | conroe
# Processing Record 14 of Set 7 | qaanaaq
# Processing Record 15 of Set 7 | paamiut
# Processing Record 16 of Set 7 | ambovombe
# Processing Record 17 of Set 7 | kaitangata
# Processing Record 18 of Set 7 | faya
# Processing Record 19 of Set 7 | abnub
# Processing Record 20 of Set 7 | moirang
# Processing Record 21 of Set 7 | havre-saint-pierre
# Processing Record 22 of Set 7 | sobolevo
# Processing Record 23 of Set 7 | aswan
# Processing Record 24 of Set 7 | shizunai
# Processing Record 25 of Set 7 | miraflores
# Processing Record 26 of Set 7 | alice springs
# Processing Record 27 of Set 7 | yirol
# City not found. Skipping...
# Processing Record 28 of Set 7 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 29 of Set 7 | huancavelica
# Processing Record 30 of Set 7 | yabrud
# Processing Record 31 of Set 7 | yate
# Processing Record 32 of Set 7 | broken hill
# Processing Record 33 of Set 7 | jacareacanga
# Processing Record 34 of Set 7 | harrismith
# Processing Record 35 of Set 7 | rawson
# Processing Record 36 of Set 7 | mecca
# Processing Record 37 of Set 7 | kruisfontein
# Processing Record 38 of Set 7 | molepolole
# Processing Record 39 of Set 7 | finale ligure
# Processing Record 40 of Set 7 | kirkwall
# Processing Record 41 of Set 7 | bubaque
# Processing Record 42 of Set 7 | turbat
# Processing Record 43 of Set 7 | talcahuano
# Processing Record 44 of Set 7 | raposa
# Processing Record 45 of Set 7 | pisco
# Processing Record 46 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 47 of Set 7 | airai
# Processing Record 48 of Set 7 | lodja
# Processing Record 49 of Set 7 | posse
# Processing Record 50 of Set 7 | kotido
# Processing Record 1 of Set 8 | straseni
# Processing Record 2 of Set 8 | strezhevoy
# Processing Record 3 of Set 8 | rosarito
# Processing Record 4 of Set 8 | insar
# Processing Record 5 of Set 8 | zhanaozen
# Processing Record 6 of Set 8 | hasaki
# Processing Record 7 of Set 8 | grodzisk mazowiecki
# Processing Record 8 of Set 8 | ayagoz
# Processing Record 9 of Set 8 | mehamn
# Processing Record 10 of Set 8 | songling
# Processing Record 11 of Set 8 | dong hoi
# Processing Record 12 of Set 8 | maniitsoq
# Processing Record 13 of Set 8 | taburi
# City not found. Skipping...
# Processing Record 14 of Set 8 | muros
# Processing Record 15 of Set 8 | union
# Processing Record 16 of Set 8 | port hardy
# Processing Record 17 of Set 8 | batemans bay
# Processing Record 18 of Set 8 | cam ranh
# Processing Record 19 of Set 8 | ayan
# Processing Record 20 of Set 8 | ahuimanu
# Processing Record 21 of Set 8 | kansanshi
# Processing Record 22 of Set 8 | srednekolymsk
# Processing Record 23 of Set 8 | belaya gora
# Processing Record 24 of Set 8 | uyskoye
# Processing Record 25 of Set 8 | kochki
# Processing Record 26 of Set 8 | tlahualilo
# City not found. Skipping...
# Processing Record 27 of Set 8 | hendijan
# City not found. Skipping...
# Processing Record 28 of Set 8 | aleksandro-nevskiy
# Processing Record 29 of Set 8 | porto novo
# Processing Record 30 of Set 8 | arnprior
# Processing Record 31 of Set 8 | bud
# Processing Record 32 of Set 8 | kamina
# Processing Record 33 of Set 8 | takoradi
# Processing Record 34 of Set 8 | jahrom
# City not found. Skipping...
# Processing Record 35 of Set 8 | tanete
# Processing Record 36 of Set 8 | birjand
# Processing Record 37 of Set 8 | mackay
# Processing Record 38 of Set 8 | sabha
# Processing Record 39 of Set 8 | constantine
# Processing Record 40 of Set 8 | margate
# Processing Record 41 of Set 8 | nishihara
# Processing Record 42 of Set 8 | maputo
# Processing Record 43 of Set 8 | sayyan
# Processing Record 44 of Set 8 | barra do corda
# Processing Record 45 of Set 8 | carmo do paranaiba
# Processing Record 46 of Set 8 | nova russas
# Processing Record 47 of Set 8 | henties bay
# Processing Record 48 of Set 8 | necochea
# Processing Record 49 of Set 8 | jumla
# Processing Record 50 of Set 8 | matara
# Processing Record 1 of Set 9 | aykhal
# Processing Record 2 of Set 9 | ilulissat
# Processing Record 3 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 4 of Set 9 | jaisalmer
# Processing Record 5 of Set 9 | vryburg
# Processing Record 6 of Set 9 | lokosovo
# Processing Record 7 of Set 9 | graaff-reinet
# Processing Record 8 of Set 9 | san policarpo
# Processing Record 9 of Set 9 | moron
# Processing Record 10 of Set 9 | tuggurt
# City not found. Skipping...
# Processing Record 11 of Set 9 | goderich
# Processing Record 12 of Set 9 | selimpasa
# Processing Record 13 of Set 9 | fort nelson
# Processing Record 14 of Set 9 | isangel
# Processing Record 15 of Set 9 | fasa
# Processing Record 16 of Set 9 | sola
# Processing Record 17 of Set 9 | nanortalik
# Processing Record 18 of Set 9 | jerusalem
# Processing Record 19 of Set 9 | pervomayskiy
# Processing Record 20 of Set 9 | dingle
# Processing Record 21 of Set 9 | guilin
# Processing Record 22 of Set 9 | marang
# Processing Record 23 of Set 9 | lhokseumawe
# Processing Record 24 of Set 9 | pierre
# Processing Record 25 of Set 9 | najran
# Processing Record 26 of Set 9 | juquitiba
# Processing Record 27 of Set 9 | urucara
# Processing Record 28 of Set 9 | west wendover
# Processing Record 29 of Set 9 | shu
# Processing Record 30 of Set 9 | boyolangu
# Processing Record 31 of Set 9 | kapitanivka
# Processing Record 32 of Set 9 | cayenne
# Processing Record 33 of Set 9 | bandarbeyla
# Processing Record 34 of Set 9 | robertson
# Processing Record 35 of Set 9 | adrar
# Processing Record 36 of Set 9 | manati
# Processing Record 37 of Set 9 | guozhen
# Processing Record 38 of Set 9 | olafsvik
# Processing Record 39 of Set 9 | kitzbuhel
# Processing Record 40 of Set 9 | korla
# Processing Record 41 of Set 9 | georgetown
# Processing Record 42 of Set 9 | terrace
# Processing Record 43 of Set 9 | sisimiut
# Processing Record 44 of Set 9 | robe
# Processing Record 45 of Set 9 | shieli
# Processing Record 46 of Set 9 | saint-prosper
# Processing Record 47 of Set 9 | goure
# Processing Record 48 of Set 9 | bambanglipuro
# Processing Record 49 of Set 9 | port macquarie
# Processing Record 50 of Set 9 | polyarnyy
# Processing Record 1 of Set 10 | torbay
# Processing Record 2 of Set 10 | baruun-urt
# Processing Record 3 of Set 10 | broome
# Processing Record 4 of Set 10 | dovers
# Processing Record 5 of Set 10 | hurricane
# Processing Record 6 of Set 10 | iralaya
# Processing Record 7 of Set 10 | novoagansk
# Processing Record 8 of Set 10 | coihaique
# Processing Record 9 of Set 10 | busayra
# Processing Record 10 of Set 10 | poya
# Processing Record 11 of Set 10 | gorin
# Processing Record 12 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 13 of Set 10 | miquelon
# Processing Record 14 of Set 10 | taltal
# Processing Record 15 of Set 10 | poum
# Processing Record 16 of Set 10 | dolores
# Processing Record 17 of Set 10 | benguela
# Processing Record 18 of Set 10 | coahuayana
# Processing Record 19 of Set 10 | nova ushytsya
# Processing Record 20 of Set 10 | arlit
# Processing Record 21 of Set 10 | zheleznodorozhnyy
# Processing Record 22 of Set 10 | hervey bay
# Processing Record 23 of Set 10 | swift current
# Processing Record 24 of Set 10 | saldanha
# Processing Record 25 of Set 10 | leningradskiy
# Processing Record 26 of Set 10 | pevek
# Processing Record 27 of Set 10 | conde
# Processing Record 28 of Set 10 | champerico
# Processing Record 29 of Set 10 | micheweni
# Processing Record 30 of Set 10 | los llanos de aridane
# Processing Record 31 of Set 10 | berlevag
# Processing Record 32 of Set 10 | tumarbong
# Processing Record 33 of Set 10 | nekhayevskiy
# Processing Record 34 of Set 10 | hobyo
# Processing Record 35 of Set 10 | yatou
# Processing Record 36 of Set 10 | camacha
# Processing Record 37 of Set 10 | cuenca
# Processing Record 38 of Set 10 | mahajanga
# Processing Record 39 of Set 10 | namatanai
# Processing Record 40 of Set 10 | undory
# Processing Record 41 of Set 10 | akureyri
# Processing Record 42 of Set 10 | dillon
# Processing Record 43 of Set 10 | gafanha da encarnacao
# Processing Record 44 of Set 10 | nueve de julio
# Processing Record 45 of Set 10 | vanimo
# Processing Record 46 of Set 10 | tulsipur
# Processing Record 47 of Set 10 | college
# Processing Record 48 of Set 10 | rio grande
# Processing Record 49 of Set 10 | skibbereen
# Processing Record 50 of Set 10 | evensk
# Processing Record 1 of Set 11 | vostok
# Processing Record 2 of Set 11 | shenjiamen
# Processing Record 3 of Set 11 | villa oliva
# City not found. Skipping...
# Processing Record 4 of Set 11 | kabalo
# Processing Record 5 of Set 11 | catamarca
# Processing Record 6 of Set 11 | guerrero negro
# Processing Record 7 of Set 11 | lichinga
# Processing Record 8 of Set 11 | la quinta
# Processing Record 9 of Set 11 | gramada
# Processing Record 10 of Set 11 | flinders
# Processing Record 11 of Set 11 | litovko
# Processing Record 12 of Set 11 | tautira
# Processing Record 13 of Set 11 | grants pass
# Processing Record 14 of Set 11 | taian
# Processing Record 15 of Set 11 | avera
# Processing Record 16 of Set 11 | norman wells
# Processing Record 17 of Set 11 | la tuque
# Processing Record 18 of Set 11 | beipiao
# Processing Record 19 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 11 | lukhovitsy
# Processing Record 21 of Set 11 | sur
# Processing Record 22 of Set 11 | kastamonu
# Processing Record 23 of Set 11 | obera
# Processing Record 24 of Set 11 | yen bai
# Processing Record 25 of Set 11 | ust-omchug
# Processing Record 26 of Set 11 | mosetse
# Processing Record 27 of Set 11 | amapa
# Processing Record 28 of Set 11 | werda
# Processing Record 29 of Set 11 | labrea
# Processing Record 30 of Set 11 | phuket
# Processing Record 31 of Set 11 | tottori
# Processing Record 32 of Set 11 | narsaq
# Processing Record 33 of Set 11 | feuchtwangen
# Processing Record 34 of Set 11 | anloga
# Processing Record 35 of Set 11 | tiquisio
# Processing Record 36 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 11 | turukhansk
# Processing Record 38 of Set 11 | yar-sale
# Processing Record 39 of Set 11 | bereda
# Processing Record 40 of Set 11 | qingdao
# Processing Record 41 of Set 11 | savannah bight
# Processing Record 42 of Set 11 | ambilobe
# Processing Record 43 of Set 11 | curup
# Processing Record 44 of Set 11 | labuhan
# Processing Record 45 of Set 11 | miri
# Processing Record 46 of Set 11 | esil
# Processing Record 47 of Set 11 | karratha
# Processing Record 48 of Set 11 | lashio
# Processing Record 49 of Set 11 | puerto del rosario
# Processing Record 50 of Set 11 | burnie
# Processing Record 1 of Set 12 | imbituba
# Processing Record 2 of Set 12 | kamsack
# Processing Record 3 of Set 12 | carlisle
# Processing Record 4 of Set 12 | horsham
# Processing Record 5 of Set 12 | palencia
# Processing Record 6 of Set 12 | el fuerte
# Processing Record 7 of Set 12 | raudeberg
# Processing Record 8 of Set 12 | totma
# Processing Record 9 of Set 12 | merauke
# Processing Record 10 of Set 12 | aksarka
# Processing Record 11 of Set 12 | kerchevskiy
# Processing Record 12 of Set 12 | morondava
# Processing Record 13 of Set 12 | dindigul
# Processing Record 14 of Set 12 | takab
# Processing Record 15 of Set 12 | krasnyy yar
# Processing Record 16 of Set 12 | sao miguel do araguaia
# Processing Record 17 of Set 12 | minab
# Processing Record 18 of Set 12 | asau
# Processing Record 19 of Set 12 | makaha
# Processing Record 20 of Set 12 | brigantine
# Processing Record 21 of Set 12 | labytnangi
# Processing Record 22 of Set 12 | quesnel
# Processing Record 23 of Set 12 | tefe
# Processing Record 24 of Set 12 | vernon
# Processing Record 25 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 26 of Set 12 | winton
# Processing Record 27 of Set 12 | whitehorse
# Processing Record 28 of Set 12 | manzhouli
# Processing Record 29 of Set 12 | makinsk
# Processing Record 30 of Set 12 | inhambane
# Processing Record 31 of Set 12 | rockhampton
# Processing Record 32 of Set 12 | keti bandar
# Processing Record 33 of Set 12 | riyadh
# Processing Record 34 of Set 12 | boguchany
# Processing Record 35 of Set 12 | orodara
# Processing Record 36 of Set 12 | khagrachari
# City not found. Skipping...
# Processing Record 37 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 38 of Set 12 | taitung
# Processing Record 39 of Set 12 | east wenatchee bench
# Processing Record 40 of Set 12 | aquitania
# Processing Record 41 of Set 12 | liepaja
# Processing Record 42 of Set 12 | rundu
# Processing Record 43 of Set 12 | vallenar
# Processing Record 44 of Set 12 | othonoi
# City not found. Skipping...
# Processing Record 45 of Set 12 | peshkopi
# Processing Record 46 of Set 12 | kushiro
# Processing Record 47 of Set 12 | tandur
# Processing Record 48 of Set 12 | aracati
# Processing Record 49 of Set 12 | lompoc
# Processing Record 50 of Set 12 | basoko
# Processing Record 1 of Set 13 | fortuna
# Processing Record 2 of Set 13 | dukat
# Processing Record 3 of Set 13 | laguna
# Processing Record 4 of Set 13 | laerdalsoyri
# Processing Record 5 of Set 13 | northam
# Processing Record 6 of Set 13 | bemidji
# Processing Record 7 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 13 | grand-santi
# Processing Record 9 of Set 13 | alofi
# Processing Record 10 of Set 13 | honggang
# Processing Record 11 of Set 13 | kushmurun
# Processing Record 12 of Set 13 | antalaha
# Processing Record 13 of Set 13 | stephenville crossing
# Processing Record 14 of Set 13 | galveston
# Processing Record 15 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 16 of Set 13 | santa cruz
# Processing Record 17 of Set 13 | gat
# Processing Record 18 of Set 13 | heilbron
# Processing Record 19 of Set 13 | sabang
# Processing Record 20 of Set 13 | arkhipo-osipovka
# Processing Record 21 of Set 13 | ambon
# Processing Record 22 of Set 13 | matagami
# Processing Record 23 of Set 13 | okha
# Processing Record 24 of Set 13 | tyukalinsk
# Processing Record 25 of Set 13 | bosaso
# Processing Record 26 of Set 13 | sinnamary
# Processing Record 27 of Set 13 | nelson bay
# Processing Record 28 of Set 13 | tazovskiy
# Processing Record 29 of Set 13 | newport
# Processing Record 30 of Set 13 | sinazongwe
# Processing Record 31 of Set 13 | maltahohe
# Processing Record 32 of Set 13 | shache
# Processing Record 33 of Set 13 | chumikan
# Processing Record 34 of Set 13 | diego de almagro
# Processing Record 35 of Set 13 | green river
# Processing Record 36 of Set 13 | huaraz
# Processing Record 37 of Set 13 | xining
# Processing Record 38 of Set 13 | gombe
# Processing Record 39 of Set 13 | thinadhoo
# Processing Record 40 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 41 of Set 13 | cache creek
# Processing Record 42 of Set 13 | karaton
# Processing Record 43 of Set 13 | copiapo
# Processing Record 44 of Set 13 | kaniama
# Processing Record 45 of Set 13 | morgan city
# Processing Record 46 of Set 13 | shelburne
# Processing Record 47 of Set 13 | makung
# City not found. Skipping...
# Processing Record 48 of Set 13 | kortkeros
# Processing Record 49 of Set 13 | boa vista
# Processing Record 50 of Set 13 | panino
# Processing Record 1 of Set 14 | iberia
# Processing Record 2 of Set 14 | port augusta
# Processing Record 3 of Set 14 | canutama
# Processing Record 4 of Set 14 | mao
# Processing Record 5 of Set 14 | tuscaloosa
# Processing Record 6 of Set 14 | son la
# Processing Record 7 of Set 14 | ikungi
# Processing Record 8 of Set 14 | cabinda
# Processing Record 9 of Set 14 | zavitinsk
# Processing Record 10 of Set 14 | fort collins
# Processing Record 11 of Set 14 | nioro
# Processing Record 12 of Set 14 | chapada dos guimaraes
# Processing Record 13 of Set 14 | deskati
# Processing Record 14 of Set 14 | tiznit
# Processing Record 15 of Set 14 | ahumada
# City not found. Skipping...
# Processing Record 16 of Set 14 | maldonado
# Processing Record 17 of Set 14 | balkhash
# Processing Record 18 of Set 14 | baherden
# Processing Record 19 of Set 14 | annaka
# Processing Record 20 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 21 of Set 14 | arawa
# Processing Record 22 of Set 14 | bama
# Processing Record 23 of Set 14 | willowmore
# Processing Record 24 of Set 14 | makakilo city
# Processing Record 25 of Set 14 | hambantota
# Processing Record 26 of Set 14 | huarmey
# Processing Record 27 of Set 14 | alugan
# Processing Record 28 of Set 14 | mato verde
# Processing Record 29 of Set 14 | ningan
# City not found. Skipping...
# Processing Record 30 of Set 14 | hamilton
# Processing Record 31 of Set 14 | matadi
# Processing Record 32 of Set 14 | jabiru
# City not found. Skipping...
# Processing Record 33 of Set 14 | baijiantan
# Processing Record 34 of Set 14 | sambava
# Processing Record 35 of Set 14 | ukiah
# Processing Record 36 of Set 14 | roald
# Processing Record 37 of Set 14 | kargopol
# Processing Record 38 of Set 14 | nome
# Processing Record 39 of Set 14 | neuquen
# Processing Record 40 of Set 14 | ozernovskiy
# Processing Record 41 of Set 14 | greensburg
# Processing Record 42 of Set 14 | red bluff
# Processing Record 43 of Set 14 | one hundred mile house
# City not found. Skipping...
# Processing Record 44 of Set 14 | proletarsk
# Processing Record 45 of Set 14 | tutoia
# Processing Record 46 of Set 14 | klyuchi
# Processing Record 47 of Set 14 | marystown
# Processing Record 48 of Set 14 | solovetskiy
# City not found. Skipping...
# Processing Record 49 of Set 14 | chute-aux-outardes
# Processing Record 50 of Set 14 | kununurra
# Processing Record 1 of Set 15 | odessa
# Processing Record 2 of Set 15 | gornoye loo
# Processing Record 3 of Set 15 | salekhard
# Processing Record 4 of Set 15 | lemesos
# City not found. Skipping...
# Processing Record 5 of Set 15 | totness
# Processing Record 6 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 7 of Set 15 | jaguarao
# Processing Record 8 of Set 15 | maloy
# Processing Record 9 of Set 15 | noumea
# Processing Record 10 of Set 15 | wenling
# Processing Record 11 of Set 15 | batsfjord
# Processing Record 12 of Set 15 | maragogi
# Processing Record 13 of Set 15 | cabedelo
# Processing Record 14 of Set 15 | ewa beach
# Processing Record 15 of Set 15 | nadym
# Processing Record 16 of Set 15 | nanning
# Processing Record 17 of Set 15 | gizo
# Processing Record 18 of Set 15 | promyshlennaya
# Processing Record 19 of Set 15 | ojinaga
# Processing Record 20 of Set 15 | lusambo
# Processing Record 21 of Set 15 | palmer
# Processing Record 22 of Set 15 | marzuq
# Processing Record 23 of Set 15 | kaohsiung
# Processing Record 24 of Set 15 | san martin
# Processing Record 25 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 15 | cap malheureux
# Processing Record 27 of Set 15 | progreso
# Processing Record 28 of Set 15 | capaccio
# Processing Record 29 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 30 of Set 15 | evanston
# Processing Record 31 of Set 15 | sira
# Processing Record 32 of Set 15 | kem
# Processing Record 33 of Set 15 | oriximina
# Processing Record 34 of Set 15 | watertown
# Processing Record 35 of Set 15 | udachnyy
# Processing Record 36 of Set 15 | nedryhayliv
# Processing Record 37 of Set 15 | asekeyevo
# Processing Record 38 of Set 15 | lorengau
# Processing Record 39 of Set 15 | saint-francois
# Processing Record 40 of Set 15 | kroya
# Processing Record 41 of Set 15 | jasper
# Processing Record 42 of Set 15 | farias brito
# Processing Record 43 of Set 15 | luanda
# Processing Record 44 of Set 15 | princeton
# Processing Record 45 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 15 | scarborough
# Processing Record 47 of Set 15 | sao jose da coroa grande
# Processing Record 48 of Set 15 | baykit
# Processing Record 49 of Set 15 | kaeo
# Processing Record 50 of Set 15 | morales
# Processing Record 1 of Set 16 | kudahuvadhoo
# Processing Record 2 of Set 16 | charlestown
# Processing Record 3 of Set 16 | jiexiu
# Processing Record 4 of Set 16 | ondjiva
# Processing Record 5 of Set 16 | kasongo-lunda
# Processing Record 6 of Set 16 | halalo
# City not found. Skipping...
# Processing Record 7 of Set 16 | nagua
# Processing Record 8 of Set 16 | lakatoro
# Processing Record 9 of Set 16 | pangkalanbuun
# Processing Record 10 of Set 16 | marsa matruh
# Processing Record 11 of Set 16 | roberval
# Processing Record 12 of Set 16 | rocha
# Processing Record 13 of Set 16 | teya
# Processing Record 14 of Set 16 | babanusah
# City not found. Skipping...
# Processing Record 15 of Set 16 | koboldo
# City not found. Skipping...
# Processing Record 16 of Set 16 | wasilla
# Processing Record 17 of Set 16 | talakan
# Processing Record 18 of Set 16 | macusani
# Processing Record 19 of Set 16 | flin flon
# Processing Record 20 of Set 16 | kuruksay
# City not found. Skipping...
# Processing Record 21 of Set 16 | khorixas
# Processing Record 22 of Set 16 | phalodi
# Processing Record 23 of Set 16 | ashland
# Processing Record 24 of Set 16 | ruthin
# Processing Record 25 of Set 16 | bairiki
# Processing Record 26 of Set 16 | businga
# Processing Record 27 of Set 16 | alto araguaia
# Processing Record 28 of Set 16 | ajra
# Processing Record 29 of Set 16 | subang
# Processing Record 30 of Set 16 | itarema
# Processing Record 31 of Set 16 | beringovskiy
# Processing Record 32 of Set 16 | denham springs
# Processing Record 33 of Set 16 | staroaleyskoye
# Processing Record 34 of Set 16 | sembe
# Processing Record 35 of Set 16 | tessalit
# Processing Record 36 of Set 16 | mangrol
# Processing Record 37 of Set 16 | hofn
# Processing Record 38 of Set 16 | jujuy
# City not found. Skipping...
# Processing Record 39 of Set 16 | tabou
# Processing Record 40 of Set 16 | saint-augustin
# Processing Record 41 of Set 16 | moussoro
# Processing Record 42 of Set 16 | two rivers
# Processing Record 43 of Set 16 | lalomanu
# City not found. Skipping...
# Processing Record 44 of Set 16 | metro
# Processing Record 45 of Set 16 | san vicente
# Processing Record 46 of Set 16 | karasjok
# Processing Record 47 of Set 16 | salinopolis
# Processing Record 48 of Set 16 | moerai
# Processing Record 49 of Set 16 | luang prabang
# Processing Record 50 of Set 16 | nanakuli
# Processing Record 1 of Set 17 | gambela
# Processing Record 2 of Set 17 | changji
# Processing Record 3 of Set 17 | karkaralinsk
# City not found. Skipping...
# Processing Record 4 of Set 17 | pacific grove
# Processing Record 5 of Set 17 | vila do maio
# Processing Record 6 of Set 17 | pochutla
# Processing Record 7 of Set 17 | sistranda
# Processing Record 8 of Set 17 | sarai naurang
# Processing Record 9 of Set 17 | avsyunino
# Processing Record 10 of Set 17 | peniche
# Processing Record 11 of Set 17 | gasa
# Processing Record 12 of Set 17 | zdvinsk
# Processing Record 13 of Set 17 | kinanah
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 745

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Hilo      US  19.7297 -155.0900     79.29        85         100
# 1   Tasiilaq      GL  65.6145  -37.6368     17.76        61          93
# 2  Tuatapere      NZ -46.1333  167.6833     57.63        99          90
# 3      Jambi      ID  -1.6000  103.6167     86.99        63          94
# 4    Rikitea      PF -23.1203 -134.9692     73.31        79          87
# 5    Ushuaia      AR -54.8000  -68.3000     49.66        71          75
# 6     Albany      US  42.6001  -73.9662     35.67        90         100
# 7      Bilma      NE  18.6853   12.9164     67.82        19         100
# 8     Padang      ID  -0.9492  100.3543     84.51        64          63
# 9      Vaini      TO -21.2000 -175.2000     82.56        78          20
#
#    Wind Speed Weather Description
# 0        5.75     overcast clouds
# 1        3.27     overcast clouds
# 2        2.84          light rain
# 3        3.29     overcast clouds
# 4        9.42          light rain
# 5        2.30       broken clouds
# 6        1.99                snow
# 7        7.99     overcast clouds
# 8        4.14       broken clouds
# 9       16.11          light rain

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Weather Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]
# Recreate the DataFrame by using the new column order
# YOUR CODE HERE
city_data_df = city_data_df[new_column_order]
# Display sample data
# YOUR CODE HERE
city_data_df.head(10)
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Hilo      US  19.7297 -155.0900     79.29        85         100
# 1   Tasiilaq      GL  65.6145  -37.6368     17.76        61          93
# 2  Tuatapere      NZ -46.1333  167.6833     57.63        99          90
# 3      Jambi      ID  -1.6000  103.6167     86.99        63          94
# 4    Rikitea      PF -23.1203 -134.9692     73.31        79          87
# 5    Ushuaia      AR -54.8000  -68.3000     49.66        71          75
# 6     Albany      US  42.6001  -73.9662     35.67        90         100
# 7      Bilma      NE  18.6853   12.9164     67.82        19         100
# 8     Padang      ID  -0.9492  100.3543     84.51        64          63
# 9      Vaini      TO -21.2000 -175.2000     82.56        78          20
#
#    Wind Speed Weather Description
# 0        5.75     overcast clouds
# 1        3.27     overcast clouds
# 2        2.84          light rain
# 3        3.29     overcast clouds
# 4        9.42          light rain
# 5        2.30       broken clouds
# 6        1.99                snow
# 7        7.99     overcast clouds
# 8        4.14       broken clouds
# 9       16.11          light rain

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Weather Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# YOUR CODE HERE
output_data_file = "WeatherPy_Database.csv"
# Export the city_data DataFrame into a CSV file
# YOUR CODE HERE
city_data_df.to_csv(output_data_file, index_label="City_ID")
