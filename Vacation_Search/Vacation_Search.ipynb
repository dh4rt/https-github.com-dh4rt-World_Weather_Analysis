# %% [markdown]
# # Deliverable 2. Create a Customer Travel Destinations Map
#
# ----
#
# 1. Create a folder called `Vacation_Search` to save all the files related with this deliverable.
#
# 2. Download the `Vacation_Search_starter_code.ipynb` Jupyter notebook,save it into your `Vacation_Search folder`, and rename it as `Vacation_Search.ipynb`.
#
# 3. In the `Vacation_Search.ipynb` file, ensure that the dependencies and the Geoapify API key is imported correctly.
#
# 4. From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`.
#
# 5. Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation.
#
# 6. Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`.
#
# 7. Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows.
#
# 8. Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng".
#
# 9. Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame.
#
# 10. Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city.
#
# 11. Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found".
#
# 12. Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`.
#
# 13. Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the Vacation_Search folder.
#
# 14. Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame. In the point for each city add:
#
#     * The city name
#
#     * The country code
#
#     * The weather description
#
#     * The point's size should be the maximum temperature for the city
#
# 15. Take a screenshot of your map and save it to the `Vacation_Search` folder as `WeatherPy_vacation_map.png`.
#
# ---

# %% [markdown]
# ## Ensure that the dependencies and the Geoapify API key is imported correctly

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# Import API key
from config import geoapify_key

# %% [markdown]
# ## From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`

# %%
# Import the WeatherPy_database.csv file. 
# YOUR CODE HERE
city_data_df = pd.read_csv("../Weather_Database/WeatherPy_Database.csv")
# Display sample data
# YOUR CODE HERE
city_data_df.head()
# Out:
#    City_ID       City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0       Hilo      US  19.7297 -155.0900     79.29        85
# 1        1   Tasiilaq      GL  65.6145  -37.6368     17.76        61
# 2        2  Tuatapere      NZ -46.1333  167.6833     57.63        99
# 3        3      Jambi      ID  -1.6000  103.6167     86.99        63
# 4        4    Rikitea      PF -23.1203 -134.9692     73.31        79
#
#    Cloudiness  Wind Speed Weather Description
# 0         100        5.75     overcast clouds
# 1          93        3.27     overcast clouds
# 2          90        2.84          light rain
# 3          94        3.29     overcast clouds
# 4          87        9.42          light rain

# %% [markdown]
# ## Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation

# %%
# Prompt the user to enter minimum and maximum temperature criteria.
# YOUR CODE HERE
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 70
# What is the maximum temperature you would like for your trip? 90

# %% [markdown]
# ## Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`

# %%
# Filter the city_data_df DataFrame to find the cities that fit the criteria using the loc method.
preferred_cities_df = city_data_df.loc[
    (city_data_df["Max Temp"] <= max_temp) & (city_data_df["Max Temp"] >= min_temp)
]
# Display sample data
preferred_cities_df.head(10)
# Out:
#     City_ID       City Country      Lat       Lng  Max Temp  Humidity  \
# 0         0       Hilo      US  19.7297 -155.0900     79.29        85
# 3         3      Jambi      ID  -1.6000  103.6167     86.99        63
# 4         4    Rikitea      PF -23.1203 -134.9692     73.31        79
# 8         8     Padang      ID  -0.9492  100.3543     84.51        64
# 9         9      Vaini      TO -21.2000 -175.2000     82.56        78
# 11       11      Kapaa      US  22.0752 -159.3190     79.12        78
# 15       15  Hithadhoo      MV  -0.6000   73.0833     81.12        72
# 16       16   Hermanus      ZA -34.4187   19.2345     70.81        90
# 17       17     Atuona      PF  -9.8000 -139.0333     78.35        79
# 18       18     Faanui      PF -16.4833 -151.7500     80.38        79
#
#     Cloudiness  Wind Speed Weather Description
# 0          100        5.75     overcast clouds
# 3           94        3.29     overcast clouds
# 4           87        9.42          light rain
# 8           63        4.14       broken clouds
# 9           20       16.11          light rain
# 11          40        9.22          light rain
# 15          88       10.60     overcast clouds
# 16          98        7.34     overcast clouds
# 17          16       17.72          few clouds
# 18         100       16.78     overcast clouds

# %% [markdown]
# ## Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows

# %%
preferred_cities_df.isnull()
# Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
# YOUR CODE HERE
clean_travel_cities_df = preferred_cities_df.dropna()
# Display sample data
clean_travel_cities_df.head()
# Out:
#    City_ID     City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0     Hilo      US  19.7297 -155.0900     79.29        85
# 3        3    Jambi      ID  -1.6000  103.6167     86.99        63
# 4        4  Rikitea      PF -23.1203 -134.9692     73.31        79
# 8        8   Padang      ID  -0.9492  100.3543     84.51        64
# 9        9    Vaini      TO -21.2000 -175.2000     82.56        78
#
#    Cloudiness  Wind Speed Weather Description
# 0         100        5.75     overcast clouds
# 3          94        3.29     overcast clouds
# 4          87        9.42          light rain
# 8          63        4.14       broken clouds
# 9          20       16.11          light rain

# %% [markdown]
# ## Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng"

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
# YOUR CODE HERE
hotel_df = clean_travel_cities_df[["City", "Country", "Max Temp", "Weather Description", "Lat", "Lng"]].copy()

hotel_df.head(10)
# Out:
#          City Country  Max Temp Weather Description      Lat       Lng
# 0        Hilo      US     79.29     overcast clouds  19.7297 -155.0900
# 3       Jambi      ID     86.99     overcast clouds  -1.6000  103.6167
# 4     Rikitea      PF     73.31          light rain -23.1203 -134.9692
# 8      Padang      ID     84.51       broken clouds  -0.9492  100.3543
# 9       Vaini      TO     82.56          light rain -21.2000 -175.2000
# 11      Kapaa      US     79.12          light rain  22.0752 -159.3190
# 15  Hithadhoo      MV     81.12     overcast clouds  -0.6000   73.0833
# 16   Hermanus      ZA     70.81     overcast clouds -34.4187   19.2345
# 17     Atuona      PF     78.35          few clouds  -9.8000 -139.0333
# 18     Faanui      PF     80.38     overcast clouds -16.4833 -151.7500

# %% [markdown]
# ## Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame

# %%
# Create a new column "Hotel Name".
# YOUR CODE HERE
hotel_df["Hotel Name"] = ""
# Display sample data
# YOUR CODE HERE
hotel_df.head(10)
# Out:
#          City Country  Max Temp Weather Description      Lat       Lng  \
# 0        Hilo      US     79.29     overcast clouds  19.7297 -155.0900
# 3       Jambi      ID     86.99     overcast clouds  -1.6000  103.6167
# 4     Rikitea      PF     73.31          light rain -23.1203 -134.9692
# 8      Padang      ID     84.51       broken clouds  -0.9492  100.3543
# 9       Vaini      TO     82.56          light rain -21.2000 -175.2000
# 11      Kapaa      US     79.12          light rain  22.0752 -159.3190
# 15  Hithadhoo      MV     81.12     overcast clouds  -0.6000   73.0833
# 16   Hermanus      ZA     70.81     overcast clouds -34.4187   19.2345
# 17     Atuona      PF     78.35          few clouds  -9.8000 -139.0333
# 18     Faanui      PF     80.38     overcast clouds -16.4833 -151.7500
#
#    Hotel Name
# 0
# 3
# 4
# 8
# 9
# 11
# 15
# 16
# 17
# 18

# %% [markdown]
# ## Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city

# %%
# Set parameters to search for a hotel
radius = 5000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
    "limit":20
}

# %% [markdown]
# ## Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found"

# %%
# Iterate through the hotel DataFrame

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude and longitude from DataFrame.
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set up the base URL for the Geoapify Places API.
    base_url = "https://api.geoapify.com/v2/places"

    # Make request and retrieve the JSON data by using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Get the first hotel from the results and store the name, if a hotel isn't found set the hotel name as "No hotel found".
    try:
        hotel_df.loc[index, "Hotel Name"] =  name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df.head(10)
# Out:
# Starting hotel search
# Hilo - nearest hotel: Dolphin Bay Hotel
# Jambi - nearest hotel: No hotel found
# Rikitea - nearest hotel: Chez Bianca & Benoit
# Padang - nearest hotel: losmen Surya
# Vaini - nearest hotel: Keleti International Resort
# Kapaa - nearest hotel: Pono Kai Resort
# Hithadhoo - nearest hotel: Pebbles Inn
# Hermanus - nearest hotel: Aloe guest house
# Atuona - nearest hotel: Pearl Resort
# Faanui - nearest hotel: Oa Oa Lodge
# Butaritari - nearest hotel: No hotel found
# Kirakira - nearest hotel: No hotel found
# Sibolga - nearest hotel: Hotel Prima Indah
# Kaili - nearest hotel: No hotel found
# Busselton - nearest hotel: No hotel found
# Narasannapeta - nearest hotel: No hotel found
# Arraial Do Cabo - nearest hotel: No hotel found
# Innisfail - nearest hotel: No hotel found
# Mattru - nearest hotel: No hotel found
# Avarua - nearest hotel: Paradise Inn
# Buala - nearest hotel: No hotel found
# Sao Gabriel Da Cachoeira - nearest hotel: Casa de Hóspedes do CFRN/5ºBIS
# Souillac - nearest hotel: Hotel SkylineInn
# Ballina - nearest hotel: Ballina Beach Resort
# Kahului - nearest hotel: Maui Seaside Hotel
# Sao Felix Do Xingu - nearest hotel: Hotel Terraço
# Pimenta Bueno - nearest hotel: Cristalina palace hotel
# Cape Town - nearest hotel: Townhouse Hotel
# Bambous Virieux - nearest hotel: No hotel found
# Biak - nearest hotel: No hotel found
# Tura - nearest hotel: No hotel found
# Manaure - nearest hotel: hotel palaima
# Puerto Ayora - nearest hotel: Hostal La Mirada De Solitario George
# Ormara - nearest hotel: No hotel found
# Camapua - nearest hotel: No hotel found
# Christchurch - nearest hotel: Ibis Hotel Christchurch
# Port Blair - nearest hotel: Andaman Ocean Breeze
# Bengkulu - nearest hotel: Dena Hotel
# San Jose De Guanipa - nearest hotel: Hotel Cel
# San Pedro - nearest hotel: Hotel Takara
# Camana - nearest hotel: Caja Arequipa
# Grand Gaube - nearest hotel: Coco Villa
# Wagga Wagga - nearest hotel: The Astor
# Sao Filipe - nearest hotel: Bela Vista
# Kokopo - nearest hotel: Hotel Kokopo
# Pontianak - nearest hotel: Golden Tulip Hotel
# Salalah - nearest hotel: Muscat International Hotel
# Quelimane - nearest hotel: Mabassa
# Sao Joao Da Barra - nearest hotel: Pousada Mediterrâneo
# Saint-Joseph - nearest hotel: No hotel found
# Kavieng - nearest hotel: Kavieng Hotel
# Qui Nhon - nearest hotel: No hotel found
# Carnarvon - nearest hotel: No hotel found
# Pak Phanang - nearest hotel: Pak Phanang Hotel
# Wawa - nearest hotel: No hotel found
# Cuambog - nearest hotel: The Beach Club at Lubi Plantation Island
# Chibuto - nearest hotel: DESHENG
# Pandan - nearest hotel: No hotel found
# Tarakan - nearest hotel: Hotel Dynasty
# Kavaratti - nearest hotel: No hotel found
# Voh - nearest hotel: Le Vook
# Piacabucu - nearest hotel: O Leão
# Vila Velha - nearest hotel: Hotel Prainha
# Umm Lajj - nearest hotel: No hotel found
# Sibu - nearest hotel: The Paramount Hotel
# Vao - nearest hotel: Nataiwatch
# Assai - nearest hotel: No hotel found
# Samarai - nearest hotel: No hotel found
# Axim - nearest hotel: Axim Beach Hotel
# San Juan Del Sur - nearest hotel: Hotel Colonial
# Miandrivazo - nearest hotel: Baobab
# Ternate - nearest hotel: Boulivard ternate
# Beloha - nearest hotel: No hotel found
# Yenagoa - nearest hotel: Peretimi Hotels Ltd.
# Mitsamiouli - nearest hotel: Hotel le Paradis
# Kalmunai - nearest hotel: Saji new food
# Bathsheba - nearest hotel: Atlantis Hotel
# Taoudenni - nearest hotel: No hotel found
# Harper - nearest hotel: No hotel found
# Saint-Philippe - nearest hotel: Le Baril
# Dhidhdhoo - nearest hotel: No hotel found
# Lagos - nearest hotel: No hotel found
# Rangapara - nearest hotel: No hotel found
# Touros - nearest hotel: Pousada Atlântico
# Ocos - nearest hotel: No hotel found
# Cockburn Town - nearest hotel: The Salt Raker Inn
# Grand-Lahou - nearest hotel: Cap Lahou
# Kulhudhuffushi - nearest hotel: No hotel found
# Vaitape - nearest hotel: Oa Oa Lodge
# Mahebourg - nearest hotel: Grand Bel Air
# Ambovombe - nearest hotel: La source
# Alice Springs - nearest hotel: Aurora Alice Springs
# Broken Hill - nearest hotel: Ibis Styles
# Jacareacanga - nearest hotel: Hotel São Cristovão
# Mecca - nearest hotel: Rehab Al Marwa Hotel 1
# Bubaque - nearest hotel: Chez Julio
# Airai - nearest hotel: No hotel found
# Dong Hoi - nearest hotel: Nhà hàng Amor Palace
# Cam Ranh - nearest hotel: Khách sạn Thái Bình
# Ahuimanu - nearest hotel: No hotel found
# Porto Novo - nearest hotel: Hôtel 6500 CFA
# Takoradi - nearest hotel: Hillcrest
# Tanete - nearest hotel: Hotel grand Sidny
# Mackay - nearest hotel: Mackay Oceanside Central Apartment Hotel
# Maputo - nearest hotel: No hotel found
# Barra Do Corda - nearest hotel: Hotel Belcho
# Nova Russas - nearest hotel: No hotel found
# Matara - nearest hotel: Villa Palm Breeze
# San Policarpo - nearest hotel: No hotel found
# Isangel - nearest hotel: Tanna Lodge
# Sola - nearest hotel: No hotel found
# Dingle - nearest hotel: No hotel found
# Marang - nearest hotel: Hotel Syahirah
# Lhokseumawe - nearest hotel: Vina Vira Hotel
# Urucara - nearest hotel: No hotel found
# Boyolangu - nearest hotel: No hotel found
# Cayenne - nearest hotel: Central Hôtel
# Bandarbeyla - nearest hotel: No hotel found
# Manati - nearest hotel: Hyatt Place - Manatí
# Georgetown - nearest hotel: Page 63 hostel
# Bambanglipuro - nearest hotel: No hotel found
# Dovers - nearest hotel: The Cotton House
# Iralaya - nearest hotel: No hotel found
# Poya - nearest hotel: No hotel found
# Poum - nearest hotel: No hotel found
# Benguela - nearest hotel: Hotel Moibela
# Hervey Bay - nearest hotel: Hervey Bay Hotel
# Conde - nearest hotel: Paladino
# Champerico - nearest hotel: Hotel y Restaurante El Submarino
# Micheweni - nearest hotel: No hotel found
# Tumarbong - nearest hotel: No hotel found
# Hobyo - nearest hotel: No hotel found
# Mahajanga - nearest hotel: Vahiny Hotel
# Namatanai - nearest hotel: Namatanai Hotel
# Vanimo - nearest hotel: CBC Guesthouse
# Catamarca - nearest hotel: Hotel de Turismo
# Tautira - nearest hotel: No hotel found
# Sur - nearest hotel: Sur Hotel
# Amapa - nearest hotel: No hotel found
# Werda - nearest hotel: No hotel found
# Labrea - nearest hotel: No hotel found
# Phuket - nearest hotel: Amanpuri
# Anloga - nearest hotel: Hotel de White House
# Tiquisio - nearest hotel: No hotel found
# Savannah Bight - nearest hotel: La Giralda
# Ambilobe - nearest hotel: Hôtel National
# Curup - nearest hotel: No hotel found
# Labuhan - nearest hotel: No hotel found
# Miri - nearest hotel: Kenyalang Suites Miri
# Lashio - nearest hotel: Golden Kaniri Hotel
# Merauke - nearest hotel: No hotel found
# Morondava - nearest hotel: Hotel Sharon Menabe
# Dindigul - nearest hotel: Hotel Zhanana Inn
# Sao Miguel Do Araguaia - nearest hotel: Hotel São Miguel
# Makaha - nearest hotel: No hotel found
# Tefe - nearest hotel: Hotel Montecarlo
# Inhambane - nearest hotel: Hotel de Inhambane
# Rockhampton - nearest hotel: Rockhampton Plaza
# Keti Bandar - nearest hotel: No hotel found
# Taitung - nearest hotel: 瑞軒民宿
# Tandur - nearest hotel: No hotel found
# Aracati - nearest hotel: Hotel Complexo Mirante das Gamboas
# Grand-Santi - nearest hotel: No hotel found
# Alofi - nearest hotel: No hotel found
# Antalaha - nearest hotel: Hôtel Florida
# Santa Cruz - nearest hotel: Aviador Hotel Boutique
# Sabang - nearest hotel: Sabang Hill
# Ambon - nearest hotel: Hotel Hero
# Bosaso - nearest hotel: Bosaso hotel
# Sinnamary - nearest hotel: Hôtel du fleuve
# Sinazongwe - nearest hotel: Lake View Lodge
# Thinadhoo - nearest hotel: No hotel found
# Karaton - nearest hotel: No hotel found
# Boa Vista - nearest hotel: Aipana Plaza Hotel
# Port Augusta - nearest hotel: Hotel Commonwealth
# Canutama - nearest hotel: No hotel found
# Cabinda - nearest hotel: Hotel Mayombe
# Chapada Dos Guimaraes - nearest hotel: Pousada Rios
# Arawa - nearest hotel: No hotel found
# Makakilo City - nearest hotel: Embassy Suites by Hilton Oahu Kapolei
# Hambantota - nearest hotel: Oasis Aurweda Resort Hambathota
# Alugan - nearest hotel: No hotel found
# Matadi - nearest hotel: Hôtel Métroplole
# Sambava - nearest hotel: Royal Sava Hôtel
# Neuquen - nearest hotel: Hotel Argentina 307
# Tutoia - nearest hotel: Pousada San Vicente
# Totness - nearest hotel: No hotel found
# Noumea - nearest hotel: Hotel Gondwana
# Maragogi - nearest hotel: Pousada Mariluz
# Cabedelo - nearest hotel: No hotel found
# Ewa Beach - nearest hotel: Hampton Inn & Suites Oahu/Kapolei
# Gizo - nearest hotel: Gizo Hotel
# Kaohsiung - nearest hotel: 寒軒國際大飯店
# San Martin - nearest hotel: Hotel Lacava
# Cap Malheureux - nearest hotel: Cape Garden
# Progreso - nearest hotel: Centro Vacacional Obrero CTM
# Sira - nearest hotel: No hotel found
# Oriximina - nearest hotel: No hotel found
# Lorengau - nearest hotel: Seeadler Bay Hotel
# Kroya - nearest hotel: Setia Hotel
# Farias Brito - nearest hotel: No hotel found
# Luanda - nearest hotel: Hotel Forum
# Princeton - nearest hotel: No hotel found
# Sao Jose Da Coroa Grande - nearest hotel: Hotel do Sol
# Kaeo - nearest hotel: No hotel found
# Kudahuvadhoo - nearest hotel: No hotel found
# Nagua - nearest hotel: hotel central
# Lakatoro - nearest hotel: No hotel found
# Pangkalanbuun - nearest hotel: Hotel Tiara
# Bairiki - nearest hotel: Marry's Motel
# Ajra - nearest hotel: No hotel found
# Subang - nearest hotel: No hotel found
# Itarema - nearest hotel: Pousada Oásis
# Sembe - nearest hotel: No hotel found
# Mangrol - nearest hotel: No hotel found
# Tabou - nearest hotel: hôtel le rochet
# Metro - nearest hotel: No hotel found
# Salinopolis - nearest hotel: Hotel Salinópolis
# Moerai - nearest hotel: Manotel Rurutu
# Luang Prabang - nearest hotel: Amantaka
# Nanakuli - nearest hotel: No hotel found
# Gambela - nearest hotel: Grand Hotel
# Vila Do Maio - nearest hotel: Residencial Jardins De Maio
# Pochutla - nearest hotel: Hotel El Patio
#          City Country  Max Temp Weather Description      Lat       Lng  \
# 0        Hilo      US     79.29     overcast clouds  19.7297 -155.0900
# 3       Jambi      ID     86.99     overcast clouds  -1.6000  103.6167
# 4     Rikitea      PF     73.31          light rain -23.1203 -134.9692
# 8      Padang      ID     84.51       broken clouds  -0.9492  100.3543
# 9       Vaini      TO     82.56          light rain -21.2000 -175.2000
# 11      Kapaa      US     79.12          light rain  22.0752 -159.3190
# 15  Hithadhoo      MV     81.12     overcast clouds  -0.6000   73.0833
# 16   Hermanus      ZA     70.81     overcast clouds -34.4187   19.2345
# 17     Atuona      PF     78.35          few clouds  -9.8000 -139.0333
# 18     Faanui      PF     80.38     overcast clouds -16.4833 -151.7500
#
#                      Hotel Name
# 0             Dolphin Bay Hotel
# 3                No hotel found
# 4          Chez Bianca & Benoit
# 8                  losmen Surya
# 9   Keleti International Resort
# 11              Pono Kai Resort
# 15                  Pebbles Inn
# 16             Aloe guest house
# 17                 Pearl Resort
# 18                  Oa Oa Lodge

# %% [markdown]
# ## Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`

# %%
# Drop the rows where there is no Hotel Name.
# YOUR CODE HERE
hotel_df[hotel_df['Hotel Name'].str.contains('No hotel found')]
hotel_df.replace('No hotel found', pd.NA, inplace = True)
clean_hotel_df = hotel_df.dropna()
# Display sample data
clean_hotel_df.head(10)
# Out:
#          City Country  Max Temp Weather Description      Lat       Lng  \
# 0        Hilo      US     79.29     overcast clouds  19.7297 -155.0900
# 4     Rikitea      PF     73.31          light rain -23.1203 -134.9692
# 8      Padang      ID     84.51       broken clouds  -0.9492  100.3543
# 9       Vaini      TO     82.56          light rain -21.2000 -175.2000
# 11      Kapaa      US     79.12          light rain  22.0752 -159.3190
# 15  Hithadhoo      MV     81.12     overcast clouds  -0.6000   73.0833
# 16   Hermanus      ZA     70.81     overcast clouds -34.4187   19.2345
# 17     Atuona      PF     78.35          few clouds  -9.8000 -139.0333
# 18     Faanui      PF     80.38     overcast clouds -16.4833 -151.7500
# 36    Sibolga      ID     84.87     overcast clouds   1.7427   98.7792
#
#                      Hotel Name
# 0             Dolphin Bay Hotel
# 4          Chez Bianca & Benoit
# 8                  losmen Surya
# 9   Keleti International Resort
# 11              Pono Kai Resort
# 15                  Pebbles Inn
# 16             Aloe guest house
# 17                 Pearl Resort
# 18                  Oa Oa Lodge
# 36            Hotel Prima Indah

# %%
clean_hotel_df.isnull()
# Out:
#       City  Country  Max Temp  Weather Description    Lat    Lng  Hotel Name
# 0    False    False     False                False  False  False       False
# 4    False    False     False                False  False  False       False
# 8    False    False     False                False  False  False       False
# 9    False    False     False                False  False  False       False
# 11   False    False     False                False  False  False       False
# ..     ...      ...       ...                  ...    ...    ...         ...
# 731  False    False     False                False  False  False       False
# 732  False    False     False                False  False  False       False
# 734  False    False     False                False  False  False       False
# 737  False    False     False                False  False  False       False
# 738  False    False     False                False  False  False       False
#
# [142 rows x 7 columns]

# %% [markdown]
# ## Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the `Vacation_Search`` folder

# %%
# Create the output File (CSV)

output_data_file = "WeatherPy_vacation.csv"
# Export the clean_hotel_df DataFrame into a CSV file

clean_hotel_df.to_csv(output_data_file, index_label="Hotels")

# %% [markdown]
# ## Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame.
#
# In the point for each city add:
#
# * The city name
# * The country code
# * The weather description
# * The point's size should be the maximum temperature for the city

# %%
# Configure the map plot
map_plot_1 = clean_hotel_df.hvplot.points(
# Configure the map

    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 1,
    color = "City",
    hover_cols = ["City", "Hotel Name", "Country", "Weather Description"]
)


# Display the map
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp,Hotel Name,Country,Weather Description)
